# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
dataset=np.random.exponential(size=1000)
plt,ax=plt.subplots(1,2)
sns.distplot(dataset,ax=ax[0])
ax[0].set_title("Original")
sns.distplot(scaled,ax=ax[1])
ax[1].set_title("Scaled")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2c0a1341d566> in <module>
#       6 sns.distplot(dataset,ax=ax[0])
#       7 ax[0].set_title("Original")
# ----> 8 sns.distplot(scaled,ax=ax[1])
#       9 ax[1].set_title("Scaled")
#
# NameError: name 'scaled' is not defined
