# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
# Out:
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\ProgramData\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
loading=load_iris()

# %%
tabulate=pd.DataFrame(loading.data,columns=loading.feature_names)

# %%
tabulate
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
tabulate.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
tabulate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# sepal length (cm)    150 non-null float64
# sepal width (cm)     150 non-null float64
# petal length (cm)    150 non-null float64
# petal width (cm)     150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
tabulate.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# dtype: object

# %%
tabulate.sort_values("sepal length (cm)",axis=0)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 13                 4.3               3.0                1.1               0.1
# 42                 4.4               3.2                1.3               0.2
# 38                 4.4               3.0                1.3               0.2
# 8                  4.4               2.9                1.4               0.2
# 41                 4.5               2.3                1.3               0.3
# ..                 ...               ...                ...               ...
# 122                7.7               2.8                6.7               2.0
# 118                7.7               2.6                6.9               2.3
# 117                7.7               3.8                6.7               2.2
# 135                7.7               3.0                6.1               2.3
# 131                7.9               3.8                6.4               2.0
#
# [150 rows x 4 columns]

# %%
tabulate.shape
# Out:
# (150, 4)

# %%
tabulate.get_dtype_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `get_dtype_counts` has been deprecated and will be removed in a future version. For DataFrames use `.dtypes.value_counts()
#   """Entry point for launching an IPython kernel.
# float64    4
# dtype: int64

# %%
tabulate.get_ftype_counts()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: get_ftype_counts is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# float64:dense    4
# dtype: int64

# %%
tabulate.style
# Out:
# <style  type="text/css" >
# </style><table id="T_a347f3e8_18ce_11eb_8069_9cb6d01ebf1a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal length (cm)</th>        <th class="col_heading level0 col1" >sepal width (cm)</th>        <th class="col_heading level0 col2" >petal length (cm)</th>        <th class="col_heading level0 col3" >petal width (cm)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a347f3e8_18ce_11eb_8069_9cb6d01ebf1alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a347f3e8_18ce_11eb_8069_9cb6d01ebf1arow0_col0" class="data row0 col0" >5.1</td>
#                         <td id="T_a347f3e8_18ce_11eb_8069_9cb6d01ebf1arow0_col1" class="data row0 col1" >3.5</td>
#                         <td id="T_a347f3e8_18ce_11eb_8069_9cb6d01ebf1arow0_col2" class="data row0 col2" >1.4</td>
# ...

# %%
tabulate.sum()
# Out:
# sepal length (cm)    876.5
# sepal width (cm)     458.6
# petal length (cm)    563.7
# petal width (cm)     179.9
# dtype: float64

# %%
tabulate.std()
# Out:
# sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %%
tabulate.size
# Out:
# 600

# %%
tabulate.ftypes
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: DataFrame.ftypes is deprecated and will be removed in a future version. Use DataFrame.dtypes instead.
#   """Entry point for launching an IPython kernel.
# sepal length (cm)    float64:dense
# sepal width (cm)     float64:dense
# petal length (cm)    float64:dense
# petal width (cm)     float64:dense
# dtype: object

# %%
tabulate.idxmax()
# Out:
# sepal length (cm)    131
# sepal width (cm)      15
# petal length (cm)    118
# petal width (cm)     100
# dtype: int64

# %%
tabulate.cumsum()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                 10.0               6.5                2.8               0.4
# 2                 14.7               9.7                4.1               0.6
# 3                 19.3              12.8                5.6               0.8
# 4                 24.3              16.4                7.0               1.0
# ..                 ...               ...                ...               ...
# 145              851.6             446.7              543.0             171.9
# 146              857.9             449.2              548.0             173.8
# 147              864.4             452.2              553.2             175.8
# 148              870.6             455.6              558.6             178.1
# 149              876.5             458.6              563.7             179.9
#
# [150 rows x 4 columns]

# %%
tabulate.cummax()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  5.1               3.5                1.4               0.2
# 2                  5.1               3.5                1.4               0.2
# 3                  5.1               3.5                1.5               0.2
# 4                  5.1               3.6                1.5               0.2
# ..                 ...               ...                ...               ...
# 145                7.9               4.4                6.9               2.5
# 146                7.9               4.4                6.9               2.5
# 147                7.9               4.4                6.9               2.5
# 148                7.9               4.4                6.9               2.5
# 149                7.9               4.4                6.9               2.5
#
# [150 rows x 4 columns]

# %%
tabulate.cummin()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.0                1.3               0.2
# 3                  4.6               3.0                1.3               0.2
# 4                  4.6               3.0                1.3               0.2
# ..                 ...               ...                ...               ...
# 145                4.3               2.0                1.0               0.1
# 146                4.3               2.0                1.0               0.1
# 147                4.3               2.0                1.0               0.1
# 148                4.3               2.0                1.0               0.1
# 149                4.3               2.0                1.0               0.1
#
# [150 rows x 4 columns]

# %%
tabulate.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029CF9D18688>,
# ...
#       dtype=object)

# %%
tabulate.var()
# Out:
# sepal length (cm)    0.685694
# sepal width (cm)     0.189979
# petal length (cm)    3.116278
# petal width (cm)     0.581006
# dtype: float64

# %%
tabulate.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
# [150 rows x 4 columns]

# %%
tabulate.idxmax()
# Out:
# sepal length (cm)    131
# sepal width (cm)      15
# petal length (cm)    118
# petal width (cm)     100
# dtype: int64

# %%
tabulate.idxmin()
# Out:
# sepal length (cm)    13
# sepal width (cm)     60
# petal length (cm)    22
# petal width (cm)      9
# dtype: int64

# %%
tabulate.isna()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
# [150 rows x 4 columns]

# %%
print(list(tabulate.items()))
# Out:
# [('sepal length (cm)', 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal length (cm), Length: 150, dtype: float64), ('sepal width (cm)', 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal width (cm), Length: 150, dtype: float64), ('petal length (cm)', 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: petal length (cm), Length: 150, dtype: float64), ('petal width (cm)', 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petal width (cm), Length: 150, dtype: float64)]

# %%
tabulate.notnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                 True              True               True              True
# 1                 True              True               True              True
# 2                 True              True               True              True
# 3                 True              True               True              True
# 4                 True              True               True              True
# ..                 ...               ...                ...               ...
# 145               True              True               True              True
# 146               True              True               True              True
# 147               True              True               True              True
# 148               True              True               True              True
# 149               True              True               True              True
#
# [150 rows x 4 columns]

# %%
tabulate.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
tabulate.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)'],
#       dtype='object')

# %%
tabulate.index
# Out:
# RangeIndex(start=0, stop=150, step=1)
